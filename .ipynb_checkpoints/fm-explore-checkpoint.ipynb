# %%
# helpful
# https://github.com/MatthewDaws/TileMapBase

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Import, and set to log to the console.  (See the console which is running
# Jupyter notebook for logging about HTTP requests.)
import tilemapbase
tilemapbase.start_logging()
# Out:
# /opt/anaconda3/envs/datasci-env/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /opt/anaconda3/envs/datasci-env/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /opt/anaconda3/envs/datasci-env/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /opt/anaconda3/envs/datasci-env/lib/python3.8/site-packages/pyproj/crs/crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
# /opt/anaconda3/envs/datasci-env/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
# /opt/anaconda3/envs/datasci-env/lib/python3.8/site-packages/pyproj/crs/crs.py:294: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   projstring = _prepare_from_string(" ".join((projstring, projkwargs)))

# %%
# Don't need if you have run before; DB file will already exist.
# tilemapbase.init(create=True)

# %%
# Use open street map
t = tilemapbase.tiles.build_OSM()

# %%
# My current office at the University of Leeds
my_office = (-93.258133, 44.986656)

degree_range = 0.005
extent = tilemapbase.Extent.from_lonlat(my_office[0] - degree_range,
                                        my_office[0] + degree_range,
                                        my_office[1] - degree_range,
                                        my_office[1] + degree_range)
extent = extent.to_aspect(1.0)
extent
# Out:
# Extent((0.2409357416666667,0.3597635612497656)->(0.24096351944444444,0.35979133902754334) projected as normal)

# %%
# On my desktop, DPI gets scaled by 0.75
fig, ax = plt.subplots(figsize=(256/100, 256/100), dpi=100)
# left = 0.5
# bottom = 0.5
# width = 0.5
# height = 0.5
# ax = fig.add_axes([left, bottom, width, height])
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.axis("off")

plotter = tilemapbase.Plotter(extent, t, width=500)
plotter.plot(ax, t)

fig.tight_layout(pad=0.01)

x, y = tilemapbase.project(*my_office)
# ax.scatter(x,y, marker=".", color="black", linewidth=20)
None

# %%
fig.savefig("test.jpg", dpi=100)

# %%
def generate_map_tiles(the_count=4):
    
    # import random
    import random
    
    # import tilemapbase
    import tilemapbase
    tilemapbase.start_logging()
    
    # Use open street map
    t = tilemapbase.tiles.build_OSM()
    
    for i in list(range(0, the_count)):
    
        # define location
        lat_top = 45.139196
        lat_bottom = 44.716657
        lon_west = -93.757479
        lon_east = -92.825981
        
        rand_lat = random.randrange(lat_bottom * 1000000, lat_top * 1000000, 100) / 1000000
        rand_lon = random.randrange(abs(lon_east) * 1000000, abs(lon_west) * 1000000, 100) / 1000000 * -1
        
        my_location = (rand_lon, rand_lat)
        print(my_location)
        
        degree_range = 0.005
        extent = tilemapbase.Extent.from_lonlat(my_location[0] - degree_range, my_location[0] + degree_range,
                      my_location[1] - degree_range, my_location[1] + degree_range)
        extent = extent.to_aspect(1.0)
        
        # On my desktop, DPI gets scaled by 0.75
        # fig, ax = plt.subplots(figsize=(6, 6), dpi=100) # this will make 600x600 pixel images
        fig, ax = plt.subplots(figsize=(256/100,256/100), dpi=100)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

        plotter = tilemapbase.Plotter(extent, t, width=600) # width=600, 
        plotter.plot(ax, t)

        fig.savefig("images/img_" + str(i) + ".jpg", dpi=100)

# %%
# %%capture
# use capture to prevent map from plotting inline (just want to save to file)

# time elapsed?

generate_map_tiles(the_count=10)

# print("My program took", time.time() - start_time, "to run")
